# %% [markdown]
# # High-Value Customer Behavior Simulation for a FinTech Subscription Service
#
# Version: v02: 2026-04-08 / v01: 2026-04-04
#
# > The Business Problem: Company CCC has a small set of "VIP Customer" data. Because of GDPR/Privacy laws, the Data Science team cannot use this data in the general development environment. They need a high-fidelity synthetic twin of these VIP customers to stress-test a new AI-driven Credit Limit model without risking real PII (Personally Identifiable Information).

# %% [markdown]
# ### Bayesian Data Science: VIP Customer Data Quality Pipeline
#
# This notebook is a wrapper for a series of notebooks that demonstrates a complete Bayesian approach to handling data corruption, missingness, imputation, and balancing for the VIP customer dataset.
#
# 1. [Data Loading & Initial Assessment](#section-1)
# 2. [Data Corruption Detection & Handling](#section-2)
# 3. [Bayesian Missing Data Analysis](#section-3)
# 4. [Bayesian Imputation Methods](#section-4)
# 5. [Data Balancing with Bayesian Resampling](#section-5)
# 6. [Final Data Quality Validation](#section-6)
# 7. [Model Readiness Assessment](#section-7)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import beta, gamma, norm, invgamma, dirichlet
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.ensemble import IsolationForest, RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.neighbors import LocalOutlierFactor
import warnings
warnings.filterwarnings('ignore')

# Bayesian-specific imports
try:
    import pymc as pm
    import arviz as az
    PYMC_AVAILABLE = True
except ImportError:
    PYMC_AVAILABLE = False
    print("⚠️ PyMC not available - using scipy.stats for Bayesian methods")

# Set visualization style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
np.random.seed(42)

print("✅ Environment ready - Bayesian Data Science Pipeline initialized")

# %% [markdown]
# ### Data Loading & Initial Assessment
#
# Load the VIP seed data and perform comprehensive initial assessment using Bayesian uncertainty quantification.

# %%
# CELL 2: Load Data with Uncertainty Quantification

# Load the dataset
df = pd.read_csv('../data/checkpoints/vip_seed.csv')

print(" === BAYESIAN DATA QUALITY ASSESSMENT - INITIAL STATE === ")
print(f"Dataset Shape: {df.shape[0]:,} rows × {df.shape[1]} columns")

# Display first few rows
print("First 10 rows:")
display(df.head(10))

# Data types and structure
print("Data Types:")
print(df.dtypes)

# Missing value analysis with Bayesian uncertainty
missing_counts = df.isnull().sum()
missing_pct = (missing_counts / len(df)) * 100

print("❌ Missing Values Analysis:")
missing_df = pd.DataFrame({
    'Missing Count': missing_counts,
    'Missing %': missing_pct.round(2),
    'Bayesian Uncertainty (95% CI)': [
        f"[{max(0, p-1.96*np.sqrt(p*(100-p)/len(df))):.2f}%, {min(100, p+1.96*np.sqrt(p*(100-p)/len(df))):.2f}%]"
        for p in missing_pct
    ]
})
print(missing_df[missing_df['Missing Count'] > 0])

# %%
# CELL 3: Data Corruption Detection

class BayesianDataCorruptionDetector:
    """Bayesian approach to detecting data corruption with uncertainty quantification."""
    
    def __init__(self, df):
        self.df = df.copy()
        self.corruption_report = {}
    
    def detect_type_corruption(self, column, expected_type):
        """Detect when values don't match expected type using Bayesian posterior."""
        if expected_type == 'numeric':
            # Check for non-numeric values
            non_numeric = pd.to_numeric(self.df[column], errors='coerce').isna() & self.df[column].notna()
            corrupted_idx = self.df[non_numeric].index.tolist()
            
            # Bayesian estimation of corruption rate
            n_corrupted = len(corrupted_idx)
            n_total = len(self.df)
            
            # Beta posterior: Beta(α + corrupted, β + total - corrupted)
            # Prior: Beta(1, 1) = Uniform
            alpha_post = 1 + n_corrupted
            beta_post = 1 + n_total - n_corrupted
            
            # 95% Credible Interval
            ci_lower = beta.ppf(0.025, alpha_post, beta_post)
            ci_upper = beta.ppf(0.975, alpha_post, beta_post)
            mean_rate = alpha_post / (alpha_post + beta_post)
            
            return {
                'type': 'type_corruption',
                'indices': corrupted_idx,
                'count': n_corrupted,
                'bayesian_rate': mean_rate,
                'credible_interval_95': (ci_lower, ci_upper),
                'severity': 'high' if mean_rate > 0.1 else 'medium' if mean_rate > 0.05 else 'low'
            }
        return None
    
    def detect_range_violations(self, column, min_val, max_val):
        """Detect values outside valid ranges with Bayesian severity assessment."""
        # Convert to numeric, handling corrupted types
        numeric_vals = pd.to_numeric(self.df[column], errors='coerce')
        
        below_min = numeric_vals < min_val
        above_max = numeric_vals > max_val
        violations = below_min | above_max
        
        violation_idx = self.df[violations].index.tolist()
        n_violations = len(violation_idx)
        
        # Bayesian analysis
        alpha_post = 1 + n_violations
        beta_post = 1 + len(self.df) - n_violations
        mean_rate = alpha_post / (alpha_post + beta_post)
        
        return {
            'type': 'range_violation',
            'column': column,
            'indices': violation_idx,
            'count': n_violations,
            'below_min': below_min.sum(),
            'above_max': above_max.sum(),
            'bayesian_rate': mean_rate,
            'severity': 'critical' if mean_rate > 0.15 else 'high' if mean_rate > 0.08 else 'medium'
        }
    
    def detect_duplicates(self):
        """Detect duplicate rows with Bayesian probability of true duplication."""
        duplicates = self.df.duplicated(keep=False)
        n_duplicates = duplicates.sum()
        
        # Bayesian: probability that a row is truly a duplicate (not just coincidence)
        # Given the continuous nature of our data, exact duplicates are almost certainly errors
        alpha_post = 1 + n_duplicates
        beta_post = 1 + len(self.df) - n_duplicates
        
        return {
            'type': 'duplicates',
            'count': n_duplicates,
            'unique_duplicated': self.df[duplicates].drop_duplicates().shape[0],
            'bayesian_rate': alpha_post / (alpha_post + beta_post),
            'indices': self.df[duplicates].index.tolist()
        }
    
    def detect_outliers_bayesian(self, column, contamination=0.05):
        """Detect outliers using Bayesian robust regression approach."""
        # Clean numeric data
        numeric_vals = pd.to_numeric(self.df[column], errors='coerce').dropna()
        
        # Fit robust model: Student-T likelihood (heavy tails)
        # Prior: Normal for mean, Half-Cauchy for scale
        median_val = np.median(numeric_vals)
