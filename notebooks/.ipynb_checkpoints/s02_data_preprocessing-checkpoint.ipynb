# %% [markdown]
# # High-Value Customer Behavior Simulation for a FinTech Subscription Service
#
# Version: v02: 2026-04-08 / v01: 2026-04-04
#
# > The Business Problem: Company CCC has a small set of "VIP Customer" data. Because of GDPR/Privacy laws, the Data Science team cannot use this data in the general development environment. They need a high-fidelity synthetic twin of these VIP customers to stress-test a new AI-driven Credit Limit model without risking real PII (Personally Identifiable Information).

# %% [markdown]
# ## SECTION S02: Data Preprocessing
#
# > Objective: Illustrate how to handle data corruption and missingness using ML and bayesian methods, data imputation and data balancing using Bayesian methods to ensure that the data has good quality, is balanced and representative so that the model which is built from it is robust.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import beta, gamma, norm, invgamma, dirichlet

# %% [markdown]
# ### Business Context:
#
# The "Dirty Data" Problem: Simulate a real-world scenario where 20% of credit_score data is missing due to API timeouts.

# %%
if '..' not in sys.path:
    sys.path.append('..')
from src.processing import introduce_nans, bayesian_impute
import pandas as pd

df = pd.read_csv('../data/raw/vip_seed.csv')
df

# %%
frequency = df['frequency'].fillna(0.0)
avg_transaction = df['avg_transaction'].fillna(0.0)
credit_score = df['credit_score'].fillna(0.0)
rfm_score = (avg_transaction / 100) * (credit_score / 700) * (frequency / 10)
vip_status = (rfm_score > np.percentile(rfm_score, 70)).astype(int)
df['vip_status'] = vip_status.fillna(0.0).astype(int)
df

# %%
df_corrupt = introduce_nans(df, proportion=0.2)
df_corrupt

# %% [markdown]
# ### Check data quality issues

# %%
# 1. Missing values (MCAR, MAR, MNAR patterns)
# MCAR: Random 5% missing in avg_transaction
mcar_idx = np.random.choice(df.index, size=int(0.05 * n_samples), replace=False)
df.loc[mcar_idx, 'avg_transaction'] = np.nan

# MAR: Missing credit_score when avg_transaction is low (10% of low-value customers)
low_value_mask = df['avg_transaction'] < np.percentile(df['avg_transaction'].dropna(), 30)
mar_idx = df[low_value_mask].sample(frac=0.10, random_state=42).index
df.loc[mar_idx, 'credit_score'] = np.nan

# MNAR: Missing frequency for VIP customers (they don't need to track frequency)
vip_mask = df['vip_status'] == 1
mnar_idx = df[vip_mask].sample(frac=0.15, random_state=42).index
df.loc[mnar_idx, 'frequency'] = np.nan
df

# %% [markdown]
# #### Detect outliers

# %%
# Extreme outliers in avg_transaction (data entry errors)
outlier_idx = np.random.choice(df.index, size=20, replace=False)
df.loc[outlier_idx, 'avg_transaction'] = df.loc[outlier_idx, 'avg_transaction'] * 50  # 50x inflation

# Impossible credit scores (< 300 or > 850)
corrupt_idx = np.random.choice(df.index, size=15, replace=False)
df.loc[corrupt_idx[:8], 'credit_score'] = np.random.randint(100, 299, 8)
df.loc[corrupt_idx[8:], 'credit_score'] = np.random.randint(851, 999, 7)

# Negative frequencies (data corruption)
neg_idx = np.random.choice(df.index, size=10, replace=False)
df.loc[neg_idx, 'frequency'] = -df.loc[neg_idx, 'frequency']
df

# %%
# 3. Duplicate records
duplicates = df.sample(n=30, random_state=42)
df = pd.concat([df, duplicates], ignore_index=True)
df

# %%
# Save the corrupted dataset to output directory
df.to_csv('../data/checkpoints/vip_seed.csv', index=False)

# %% [markdown]
# #### Data quality check

# %%
print("=== SYNTHETIC DATASET: ===")
print(f"Total samples: {len(df)}")
print(f"Features: avg_transaction, credit_score, frequency")
print(f"Target: vip_status (binary)")
print(f"\nClass distribution:")
print(df['vip_status'].value_counts())
print(f"\nMissing values:")
print(df.isnull().sum())
print(f"\nData corruption examples:")
print(f"- Credit scores outside [300, 850]: {((df['credit_score'] < 300) | (df['credit_score'] > 850)).sum()}")
print(f"- Negative frequencies: {(df['frequency'] < 0).sum()}")
print(f"- Extreme transaction outliers: {(df['avg_transaction'] > 10000).sum()}")
print(f"- Duplicate rows: {df.duplicated().sum()}")

# %% [markdown]
# ### Bayesian Data Corruption Detection

# %%
print(" === BAYESIAN DATA CORRUPTION DETECTION === ")

class BayesianDataCorruptionDetector:
    """
    Bayesian approach to detecting data corruption with uncertainty quantification.
    Uses posterior distributions to estimate corruption rates and their uncertainty.
    """
    
    def __init__(self, df):
        self.df = df.copy()
        self.corruption_report = {}
        self.correction_log = []
        
    def detect_type_corruption(self, column, expected_type='numeric'):
        """Detect when values don't match expected type using Bayesian posterior."""
        if expected_type == 'numeric':
            # Check for non-numeric values
            numeric_converted = pd.to_numeric(self.df[column], errors='coerce')
            non_numeric = numeric_converted.isna() & self.df[column].notna()
            corrupted_idx = self.df[non_numeric].index.tolist()
            
            # Bayesian estimation of corruption rate
            n_corrupted = len(corrupted_idx)
            n_total = len(self.df)
            
            # Beta posterior: Beta(α + corrupted, β + total - corrupted)
            alpha_post = 1 + n_corrupted
            beta_post = 1 + n_total - n_corrupted
            
            # 95% Credible Interval
            ci_lower = beta.ppf(0.025, alpha_post, beta_post)
            ci_upper = beta.ppf(0.975, alpha_post, beta_post)
            mean_rate = alpha_post / (alpha_post + beta_post)
            
            return {
                'column': column,
                'type': 'type_corruption',
                'indices': corrupted_idx,
                'count': n_corrupted,
                'bayesian_rate': mean_rate,
                'credible_interval_95': (ci_lower, ci_upper),
                'severity': 'high' if mean_rate > 0.1 else 'medium' if mean_rate > 0.05 else 'low',
                'sample_values': self.df.loc[corrupted_idx[:5], column].tolist() if n_corrupted > 0 else []
            }
        return None
    
    def detect_range_violations(self, column, min_val, max_val):
        """Detect values outside valid ranges with Bayesian severity assessment."""
        numeric_vals = pd.to_numeric(self.df[column], errors='coerce')
        
        below_min = numeric_vals < min_val
        above_max = numeric_vals > max_val
        violations = below_min | above_max
        
        violation_idx = self.df[violations].index.tolist()
        n_violations = violations.sum()
        
        # Bayesian analysis
        alpha_post = 1 + n_violations
        beta_post = 1 + len(self.df) - n_violations
        mean_rate = alpha_post / (alpha_post + beta_post)
        
        return {
            'column': column,
            'type': 'range_violation',
            'indices': violation_idx,
            'count': n_violations,
            'below_min': below_min.sum(),
            'above_max': above_max.sum(),
            'bayesian_rate': mean_rate,
            'credible_interval_95': (beta.ppf(0.025, alpha_post, beta_post), 
                                     beta.ppf(0.975, alpha_post, beta_post)),
            'severity': 'critical' if mean_rate > 0.15 else 'high' if mean_rate > 0.08 else 'medium'
        }
    
    def detect_duplicates(self):
        """Detect duplicate rows with Bayesian probability assessment."""
        duplicates = self.df.duplicated(keep=False)
        n_duplicates = duplicates.sum()
        
        alpha_post = 1 + n_duplicates
        beta_post = 1 + len(self.df) - n_duplicates
        
        return {
            'type': 'duplicates',
            'count': n_duplicates,
            'unique_duplicated_groups': len(self.df[duplicates].drop_duplicates()),
            'bayesian_rate': alpha_post / (alpha_post + beta_post),
            'indices': self.df[duplicates].index.tolist()
        }
    
    def detect_outliers_bayesian(self, column, prior_contamination=0.05):
        """Detect outliers using Bayesian robust regression approach with Student-T likelihood."""
        numeric_vals = pd.to_numeric(self.df[column], errors='coerce').dropna()
        
        if len(numeric_vals) < 10:
            return None
            
        # Robust statistics
        median_val = np.median(numeric_vals)
        mad_val = np.median(np.abs(numeric_vals - median_val))
        
        # Bayesian: Model data as Student-T (heavy tails) rather than Normal
        # Outliers are points with low likelihood under robust model
        standardized = (numeric_vals - median_val) / (1.4826 * mad_val + 1e-10)
        
        # Student-T likelihood with ν=4 degrees of freedom (heavy tails)
        log_likelihood = stats.t.logpdf(standardized, df=4)
        likelihood_threshold = np.percentile(log_likelihood, prior_contamination * 100)
        
        outlier_mask = log_likelihood < likelihood_threshold
        outlier_idx = numeric_vals.index[outlier_mask].tolist()
        
        # Posterior probability of being outlier
        n_outliers = outlier_mask.sum()
        alpha_post = 1 + n_outliers
        beta_post = 1 + len(numeric_vals) - n_outliers
        
        return {
            'column': column,
            'type': 'outliers',
            'indices': outlier_idx,
            'count': n_outliers,
            'bayesian_rate': alpha_post / (alpha_post + beta_post),
            'credible_interval_95': (beta.ppf(0.025, alpha_post, beta_post),
                                     beta.ppf(0.975, alpha_post, beta_post)),
            'method': 'robust_student_t',
            'threshold': likelihood_threshold
        }
    
    def generate_full_report(self):
        """Generate comprehensive corruption report with Bayesian uncertainty."""
        print("\n" + "=" * 80)
        print("🔍 BAYESIAN DATA CORRUPTION DETECTION REPORT")
        print("=" * 80)
        
        # 1. Type Corruption
        type_corr = self.detect_type_corruption('avg_transaction', 'numeric')
        if type_corr and type_corr['count'] > 0:
            self.corruption_report['type_corruption'] = type_corr
            print(f"\n📛 Type Corruption (avg_transaction):")
            print(f"   Count: {type_corr['count']} ({type_corr['bayesian_rate']*100:.2f}%)")
            print(f"   95% CI: [{type_corr['credible_interval_95'][0]*100:.2f}%, {type_corr['credible_interval_95'][1]*100:.2f}%]")
            print(f"   Severity: {type_corr['severity'].upper()}")
            print(f"   Sample: {type_corr['sample_values'][:3]}")
        
        # 2. Range Violations
        for col, (min_v, max_v) in [('credit_score', (300, 850)), ('avg_transaction', (0, 10000))]:
            range_viol = self.detect_range_violations(col, min_v, max_v)
            if range_viol['count'] > 0:
                key = f'range_violation_{col}'
                self.corruption_report[key] = range_viol
                print(f"\n🚫 Range Violations ({col}):")
                print(f"   Count: {range_viol['count']} ({range_viol['bayesian_rate']*100:.2f}%)")
                print(f"   Below min ({min_v}): {range_viol['below_min']}, Above max ({max_v}): {range_viol['above_max']}")
                print(f"   95% CI: [{range_viol['credible_interval_95'][0]*100:.2f}%, {range_viol['credible_interval_95'][1]*100:.2f}%]")
                print(f"   Severity: {range_viol['severity'].upper()}")
        
        # 3. Duplicates
        dups = self.detect_duplicates()
        if dups['count'] > 0:
            self.corruption_report['duplicates'] = dups
            print(f"\n🔁 Duplicates:")
            print(f"   Count: {dups['count']} ({dups['bayesian_rate']*100:.2f}%)")
            print(f"   Unique groups: {dups['unique_duplicated_groups']}")
        
        # 4. Outliers
        for col in ['avg_transaction', 'credit_score', 'frequency']:
            outliers = self.detect_outliers_bayesian(col)
            if outliers and outliers['count'] > 0:
                key = f'outliers_{col}'
                self.corruption_report[key] = outliers
                print(f"\n⚠️ Outliers ({col}):")
                print(f"   Count: {outliers['count']} ({outliers['bayesian_rate']*100:.2f}%)")
                print(f"   95% CI: [{outliers['credible_interval_95'][0]*100:.2f}%, {outliers['credible_interval_95'][1]*100:.2f}%]")
                print(f"   Method: {outliers['method']}")
        
        return self.corruption_report

# Instantiate and run detector
detector = BayesianDataCorruptionDetector(df)
corruption_report = detector.generate_full_report()
corruption_report
