# %% [markdown]
# # High-Value Customer Behavior Simulation for a FinTech Subscription Service
#
# Version: v02: 2026-04-08 / v01: 2026-04-04
#
# > The Business Problem: Company CCC has a small set of "VIP Customer" data. Because of GDPR/Privacy laws, the Data Science team cannot use this data in the general development environment. They need a high-fidelity synthetic twin of these VIP customers to stress-test a new AI-driven Credit Limit model without risking real PII (Personally Identifiable Information).

# %% [markdown]
# ## SECTION S01: Data Generation
#
# > Objective: Create a "Seed" dataset of VIPs and use the src/generators.py to create a synthetic population.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
# Set random seed for reproducibility
np.random.seed(42)
n_samples = 1000

# %% [markdown]
# ### Business Scenario:
#
# Define the variables: avg_transaction_value (Log-normal), transaction_frequency (Poisson), and credit_score (Normal).

# %%
# Seed Data Creation:
seed_data = pd.DataFrame({
    'avg_transaction': np.random.lognormal(mean=3, sigma=0.5, size=n_samples),
    'frequency': np.random.poisson(lam=12, size=n_samples),
    'credit_score': np.random.normal(loc=750, scale=50, size=n_samples)
})
seed_data
# seed_data.to_csv('../data/raw/vip_seed.csv', index=False)
# Out:
#      avg_transaction  frequency  credit_score
# 0          25.748003          8    810.026583
# 1          18.743890         13    757.017993
# 2          27.766889         14    651.646515
# 3          43.013539         10    694.140677
# 4          17.866426         12    740.707712
# ..               ...        ...           ...
# 995        17.451923         13    755.657023
# 996        49.345337         15    731.844167
# 997        27.672010         14    649.627157
# 998        15.095709         14    730.582653
# 999        26.743498          8    734.719044
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Discussion on alternatives to generate synthetic business data

# %% [markdown]
# #### 1. Setup Real Data (Simulating the True Correlation)
#
# > Higher credit score = Higher average transaction

# %%
credit_score = np.random.normal(650, 80, n_samples) 
credit_score = np.clip(credit_score, 300, 850)

# Generate transaction with noise based on credit score
avg_transaction = 50 + (credit_score * 0.8) + np.random.normal(0, 50, n_samples)
avg_transaction = np.clip(avg_transaction, 0, 5000)
avg_transaction[:3]

# %% [markdown]
# #### 2. Naive Random Sampling (Independence Assumption)
# > We shuffle the transactions to break the link with credit score

# %%
np.random.shuffle(avg_transaction) 
naive_transaction = avg_transaction.copy()
naive_transaction[:3]

# %%
# Create synthetic VIP customer dataset with realistic data quality issues
n_samples = 1000

# Generate base data
avg_transaction = np.random.lognormal(4.5, 0.8, n_samples)  # ~$90 average
credit_score = np.random.normal(720, 50, n_samples)  # Credit scores
frequency = np.random.poisson(12, n_samples)  # ~12 transactions/year

# Create target variable (VIP status) based on RFM-like logic
# High value customers: high avg_transaction, good credit, frequent
rfm_score = (avg_transaction / 100) * (credit_score / 700) * (frequency / 10)
vip_status = (rfm_score > np.percentile(rfm_score, 70)).astype(int)

# Create DataFrame
df = pd.DataFrame({
    'avg_transaction': avg_transaction,
    'credit_score': credit_score,
    'frequency': frequency,
    'vip_status': vip_status
})
df

# %% [markdown]
# #### 3. GAN-like Sampling (Approximated by Regression + Noise for visualization)
# > A real GAN learns this; here we simulate a "successful" GAN by learning the trend from the original data and adding noise.

# %%
mean_transaction = 50 + (credit_score * 0.8)
gan_transaction = mean_transaction + np.random.normal(0, 50, n_samples)
gan_transaction = np.clip(gan_transaction, 0, 5000)
gan_transaction[:3]

# %% [markdown]
# #### 4. Plotting

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle('Theoretical Impact of Sampling Methods on Correlation', fontsize=16)

# Plot Real Data
axs[0].scatter(credit_score, avg_transaction, alpha=0.5, color='green', s=10)
axs[0].set_title('Real World Data\n(Strong Positive Correlation)')
axs[0].set_xlabel('Credit Score')
axs[0].set_ylabel('Avg Transaction')
axs[0].grid(True, alpha=0.3)
# Add trend line
z = np.polyfit(credit_score, avg_transaction, 1)
p = np.poly1d(z)
axs[0].plot(credit_score, p(credit_score), "r--", alpha=0.5)

# Plot Naive Random
axs[1].scatter(credit_score, naive_transaction, alpha=0.5, color='red', s=10)
axs[1].set_title('Naive Random Sampling\n(Correlation Destroyed)')
axs[1].set_xlabel('Credit Score')
axs[1].set_ylabel('Avg Transaction')
axs[1].grid(True, alpha=0.3)
# Show near-zero trend
z = np.polyfit(credit_score, naive_transaction, 1)
p = np.poly1d(z)
axs[1].plot(credit_score, p(credit_score), "b--", alpha=0.5)

# Plot GAN-like Data
axs[2].scatter(credit_score, gan_transaction, alpha=0.5, color='blue', s=10)
axs[2].set_title('GAN Generated Data\n(Correlation Preserved)')
axs[2].set_xlabel('Credit Score')
axs[2].set_ylabel('Avg Transaction')
axs[2].grid(True, alpha=0.3)
# Show restored trend
z = np.polyfit(credit_score, gan_transaction, 1)
p = np.poly1d(z)
axs[2].plot(credit_score, p(credit_score), "m--", alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Synthetic Expansion
#
# Use the src module to generate 10,000 synthetic customers using three different methods.

# %%
from src.generators import get_generator

for method in ['random', 'specialized', 'gan']:
    gen = get_generator(method)
    df_synth = gen.generate(10000)
    df_synth.to_csv(f'data/synthetic/vip_{method}.csv', index=False)

# %% [markdown]
# ### Conclusion
#
# #### GANs (Joint Distribution Learning) vs Independent Marginal Sampling (Shuffling/Naive Randomization): which is better for capturing the "hidden" correlation between credit_score and avg_transaction?
#
# Standard random sampling from historical data actually preserves correlations perfectly.
#
# If you simply sample credit_score from its marginal distribution and avg_transaction from its marginal distribution independently, you destroy the relationship between them. GANs are theoretically superior in this specific context because they learn the Joint Distribution P(credit,transaction) rather than treating them as independent.
#
# In statistics, data points exist in a Joint Distribution. In our case, a person's credit_score and avg_transaction are not independent variables; they are coupled.
#
#     - High Credit Score: Often correlates with Higher Average Transactions (higher limits, more spending power).
#
#     - Low Credit Score: Often correlates with Lower Average Transactions.
#
# The "Naive Random" Approach (Marginal Sampling):
#
#     If you want to create synthetic data naively, you might sample credit_score values randomly from the list of all scores, and avg_transaction values randomly from the list of all transactions, then pair them up.
#
# In this case, you assume P(C,T)=P(C)×P(T).
#
# As a result, the correlation coefficient drops to ≈0. A low credit score is now just as likely to be paired with a massive transaction as a high credit score.
#
# As a consequence, any AI model trained on this data will learn that Credit Score does not predict Transaction behavior. This creates a catastrophically bad model for fraud detection or credit risk.
#
# The GAN Approach (Joint Distribution Learning):
#
#     A GAN consists of a Generator and a Discriminator.
#     The Generator tries to create pairs (c,t) that look real.
#     The Discriminator looks at a pair (c,t) and asks: "Does this combination exist in the real world, or are you just mixing and matching independent values?"
#
# If the Generator pairs a low credit score with a high transaction (which rarely happens in reality), the Discriminator rejects it. To fool the Discriminator, the Generator must learn the correlation.
#
# As a result, the GAN learns the shape of the joint distribution, preserving the correlation structure.
